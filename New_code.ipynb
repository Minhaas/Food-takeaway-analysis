# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# df = pd.read_csv('./new_data/zomato.csv', delimiter=',', nrows = None)
# df = pd.read_csv('./new_data/zomato.csv', sep='|', names='City', encoding='latin-1')
f = open('./new_data/zomato.csv', encoding="utf-8")
type(f)
# Out:
# _io.TextIOWrapper

# %%
df_data=pd.read_csv('./new_data/zomato.csv',encoding="latin-1")
df_country_data=pd.read_excel('./new_data/Country-Code.xlsx')

# %%
df_data.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df_data.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df_data['Currency']
# Out:
# 0       Botswana Pula(P)
# 1       Botswana Pula(P)
# 2       Botswana Pula(P)
# 3       Botswana Pula(P)
# 4       Botswana Pula(P)
#               ...
# 9546    Turkish Lira(TL)
# 9547    Turkish Lira(TL)
# 9548    Turkish Lira(TL)
# 9549    Turkish Lira(TL)
# 9550    Turkish Lira(TL)
# Name: Currency, Length: 9551, dtype: object

# %%
df_country_data.head()
# Out:
#    Country Code    Country
# 0             1      India
# 1            14  Australia
# 2            30     Brazil
# 3            37     Canada
# 4            94  Indonesia

# %%
#merged both the datasets since we are going to analyze the data based on the country name
df_Zomato=pd.merge(df_data,df_country_data,on="Country Code",how="left")
df_Zomato.head(5)
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
'''To check which country has highest number of restaurants associated with zomato, given that India contains 
highest number of restaurants with zomato, let's carry out analysis on India'''

df_Zomato1=df_Zomato.groupby("Country").agg(Restaurant_Count=("Restaurant ID","count")).sort_values(by="Restaurant_Count",ascending=False)

# %%
df_Zomato1.plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='Country'>

# %%
data = df_Zomato[df_Zomato['Country']=="India"].reset_index(drop=True).copy()
nRow1, nCol1 = data.shape
print(f'Data has {nRow1} rows and {nCol1} columns.')
# Out:
# Data has 8652 rows and 22 columns.

# %%
# Checking if dataset contains any null
data.isna().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %%
#checking no. of restaurants partnered with Zomato per city
data['City'].value_counts()
# Out:
# New Delhi       5473
# Gurgaon         1118
# Noida           1080
# Faridabad        251
# Ghaziabad         25
# Ahmedabad         21
# Guwahati          21
# Lucknow           21
# Bhubaneshwar      21
# Amritsar          21
# Pune              20
# Puducherry        20
# Patna             20
# Ludhiana          20
# Ranchi            20
# Surat             20
# Vadodara          20
# Nashik            20
# Nagpur            20
# Mysore            20
# Mumbai            20
# Varanasi          20
# Mangalore         20
# Agra              20
# Kochi             20
# Kolkata           20
# Dehradun          20
# Allahabad         20
# Aurangabad        20
# Bangalore         20
# Bhopal            20
# Chennai           20
# Coimbatore        20
# Goa               20
# Indore            20
# Jaipur            20
# Kanpur            20
# Vizag             20
# Chandigarh        18
# Hyderabad         18
# Secunderabad       2
# Panchkula          1
# Mohali             1
# ...

# %%
# To check no. of restaurants which have online delivery
data.groupby(['Has Online delivery']).size().reset_index()
# Out:
#   Has Online delivery     0
# 0                  No  6229
# 1                 Yes  2423

# %%
# sns.countplot(data['Has Online delivery'])

# %%
x=data.drop(['Cuisines','Locality', 'Longitude', 'Latitude', 'Country Code', 'Address','Locality Verbose','Switch to order menu','Currency'], axis=1)
x.head()
# Out:
#    Restaurant ID                        Restaurant Name  City  \
# 0        3400025                             Jahanpanah  Agra
# 1        3400341                    Rangrezz Restaurant  Agra
# 2        3400005                Time2Eat - Mama Chicken  Agra
# 3        3400021  Chokho Jeeman Marwari Jain Bhojanalya  Agra
# 4        3400017                         Pinch Of Spice  Agra
#
#    Average Cost for two Has Table booking Has Online delivery  \
# 0                   850                No                  No
# 1                   700                No                  No
# 2                   500                No                  No
# 3                   400                No                  No
# 4                  1000                No                  No
#
#   Is delivering now  Price range  Aggregate rating Rating color Rating text  \
# 0                No            3               3.9       Yellow        Good
# ...

# %%
# Since New Delhi has most number of restaurants partnered with zomato we can analyse which top 10 Localities has most restaurants within New Delhi 
def city_stats(df, city_name):
    x1=df[(df.City == city_name)]
    x2=x1.Locality.value_counts().head(10)
    return x2

# %%
def city_plot(df):
    df.plot(kind='bar')
    plt.ylabel('Number of Restaurants')
    plt.xlabel('Locality')
    plt.tight_layout()
    plt.show()

# %%
city_plot(city_stats(data, 'Gurgaon'))

# %%
#Logistic Regression model

#Preprocessing 

# x_test = x[x['Rating text'] == 'Not rated']

#Conversion of categorical variables to ordinal variables
#Target encoding

x['city_encoded'] = x.groupby("City")['Aggregate rating'].transform("mean")
x['restaurant_name_encoded'] = x.groupby("Restaurant Name")['Aggregate rating'].transform("mean")
x['Has Table booking'] = x['Has Table booking'].map({'Yes':1,'No':0})
x['Has Online delivery'] = x['Has Online delivery'].map({'Yes':1, 'No':0})
x['Is delivering now'] = x['Is delivering now'].map({'Yes':1, 'No':0})
x_temp_1 = pd.get_dummies(x['Rating color'], drop_first = True, prefix = 'rating_code_')
x_temp_2 = pd.get_dummies(x['Rating text'], drop_first = True, prefix = 'rating_text_')
x.drop(columns = ['Restaurant Name', 'City', 'Country'],inplace = True)

# %%
x_temp_1
# Out:
#       rating_code__Green  rating_code__Orange  rating_code__Red  \
# 0                      0                    0                 0
# 1                      0                    0                 0
# 2                      0                    0                 0
# 3                      1                    0                 0
# 4                      1                    0                 0
# ...                  ...                  ...               ...
# 8647                   0                    0                 0
# 8648                   0                    0                 0
# 8649                   1                    0                 0
# 8650                   0                    0                 0
# 8651                   1                    0                 0
#
#       rating_code__White  rating_code__Yellow
# 0                      0                    1
# 1                      0                    1
# 2                      0                    1
# ...

# %%
x_temp_2
# Out:
#       rating_text__Excellent  rating_text__Good  rating_text__Not rated  \
# 0                          0                  1                       0
# 1                          0                  1                       0
# 2                          0                  1                       0
# 3                          0                  0                       0
# 4                          0                  0                       0
# ...                      ...                ...                     ...
# 8647                       0                  1                       0
# 8648                       0                  1                       0
# 8649                       0                  0                       0
# 8650                       0                  1                       0
# 8651                       0                  0                       0
#
#       rating_text__Poor  rating_text__Very Good
# 0                     0                       0
# ...

# %%
processed_df = pd.concat([x, x_temp_1, x_temp_2], axis=1).drop(columns = ['Rating color', 'Rating text'])
processed_df.head()
# Out:
#    Restaurant ID  Average Cost for two  Has Table booking  \
# 0        3400025                   850                  0
# 1        3400341                   700                  0
# 2        3400005                   500                  0
# 3        3400021                   400                  0
# 4        3400017                  1000                  0
#
#    Has Online delivery  Is delivering now  Price range  Aggregate rating  \
# 0                    0                  0            3               3.9
# 1                    0                  0            2               3.5
# 2                    0                  0            2               3.6
# 3                    0                  0            2               4.0
# 4                    0                  0            3               4.2
#
#    Votes  city_encoded  restaurant_name_encoded  rating_code__Green  \
# 0    140         3.965                      3.9                   0
# ...

# %%
test = processed_df[processed_df['rating_text__Not rated'] == 1]
x_test = test.drop(columns = ['Aggregate rating'], axis = 1)
y_test = test['Aggregate rating']
train = processed_df[processed_df['rating_text__Not rated'] == 0]
x_train = train.drop(columns = ['Aggregate rating'], axis = 1)
y_train = train['Aggregate rating']
# x = processed_df.drop(columns = ['Aggregate rating'], axis =1)
# y = processed_df['Aggregate rating']

# from sklearn.model_selection import train_test_split
# x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=0.3)

# %%
# test.head()
# Grid search cross validation
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LinearRegression
# grid={"C":np.logspace(-3,3,7), "penalty":["l2"]}# l1 lasso l2 ridge
logreg=LinearRegression()
# logreg_cv=GridSearchCV(logreg,grid,cv=10)
logreg.fit(x_train,y_train)

# print("tuned hpyerparameters :(best parameters) ",logreg_cv.best_params_)
# print("accuracy :",logreg_cv.best_score_)
# Out:
# LinearRegression()

# %%
# from sklearn.linear_model import LogisticRegression
prediction = logreg.predict(x_test)
r2_score = logreg.score(x_test, y_test)

# %%
r2_score
# Out:
# 0.0

# %%
len(prediction)
# Out:
# 2139

# %%
pred_df = pd.DataFrame(prediction, columns = ['pred_rating'])

# %%
pred_df
# Out:
#       pred_rating
# 0        3.031616
# 1        2.731997
# 2        2.763392
# 3        2.991509
# 4        3.122609
# ...           ...
# 2134     2.750324
# 2135     2.769926
# 2136     2.759574
# 2137     2.757757
# 2138     2.767429
#
# [2139 rows x 1 columns]

# %%
pred_rating = pd.concat([x_test, pred_df], axis = 1)

# %%
pred_rating
# Out:
#       Restaurant ID  Average Cost for two  Has Table booking  \
# 247          9299.0                 100.0                0.0
# 248          9178.0                 100.0                0.0
# 249      18477319.0                 400.0                0.0
# 250      18433852.0                 300.0                0.0
# 254      18377449.0                 200.0                0.0
# ...             ...                   ...                ...
# 2134            NaN                   NaN                NaN
# 2135            NaN                   NaN                NaN
# 2136            NaN                   NaN                NaN
# 2137            NaN                   NaN                NaN
# 2138            NaN                   NaN                NaN
#
#       Has Online delivery  Is delivering now  Price range  Votes  \
# 247                   0.0                0.0          1.0    1.0
# 248                   0.0                0.0          1.0    3.0
# ...
