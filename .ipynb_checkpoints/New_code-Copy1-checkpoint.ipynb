# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# df = pd.read_csv('./new_data/zomato.csv', delimiter=',', nrows = None)
# df = pd.read_csv('./new_data/zomato.csv', sep='|', names='City', encoding='latin-1')
f = open('./new_data/zomato.csv', encoding="utf-8")
type(f)
# Out:
# _io.TextIOWrapper

# %%
df_data=pd.read_csv('./new_data/zomato.csv',encoding="latin-1")
df_country_data=pd.read_excel('./new_data/Country-Code.xlsx')

# %%
df_data.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# 3      SM Megamall, Ortigas, Mandaluyong City
# 4      SM Megamall, Ortigas, Mandaluyong City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City, Ma...  121.056831  14.581404
# 3  SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.056475  14.585318
# 4  SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.057508  14.584450
#
#                            Cuisines  ...          Currency Has Table booking  \
# 0        French, Japanese, Desserts  ...  Botswana Pula(P)               Yes
# 1                          Japanese  ...  Botswana Pula(P)               Yes
# 2  Seafood, Asian, Filipino, Indian  ...  Botswana Pula(P)               Yes
# 3                   Japanese, Sushi  ...  Botswana Pula(P)                No
# 4                  Japanese, Korean  ...  Botswana Pula(P)               Yes
#
#   Has Online delivery Is delivering now Switch to order menu Price range  \
# 0                  No                No                   No           3
# 1                  No                No                   No           3
# 2                  No                No                   No           4
# 3                  No                No                   No           4
# 4                  No                No                   No           4
#
#    Aggregate rating  Rating color Rating text Votes
# 0               4.8    Dark Green   Excellent   314
# 1               4.5    Dark Green   Excellent   591
# 2               4.4         Green   Very Good   270
# 3               4.9    Dark Green   Excellent   365
# 4               4.8    Dark Green   Excellent   229
#
# [5 rows x 21 columns]

# %%
df_country_data.head()
# Out:
#    Country Code    Country
# 0             1      India
# 1            14  Australia
# 2            30     Brazil
# 3            37     Canada
# 4            94  Indonesia

# %%
#merged both the datasets since we are going to analyze the data based on the country name
df_Zomato=pd.merge(df_data,df_country_data,on="Country Code",how="left")
df_Zomato.head(5)
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# 3      SM Megamall, Ortigas, Mandaluyong City
# 4      SM Megamall, Ortigas, Mandaluyong City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City, Ma...  121.056831  14.581404
# 3  SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.056475  14.585318
# 4  SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.057508  14.584450
#
#                            Cuisines  ...  Has Table booking  \
# 0        French, Japanese, Desserts  ...                Yes
# 1                          Japanese  ...                Yes
# 2  Seafood, Asian, Filipino, Indian  ...                Yes
# 3                   Japanese, Sushi  ...                 No
# 4                  Japanese, Korean  ...                Yes
#
#   Has Online delivery Is delivering now Switch to order menu Price range  \
# 0                  No                No                   No           3
# 1                  No                No                   No           3
# 2                  No                No                   No           4
# 3                  No                No                   No           4
# 4                  No                No                   No           4
#
#   Aggregate rating  Rating color  Rating text Votes      Country
# 0              4.8    Dark Green    Excellent   314  Phillipines
# 1              4.5    Dark Green    Excellent   591  Phillipines
# 2              4.4         Green    Very Good   270  Phillipines
# 3              4.9    Dark Green    Excellent   365  Phillipines
# 4              4.8    Dark Green    Excellent   229  Phillipines
#
# [5 rows x 22 columns]

# %%
'''To check which country has highest number of restaurants associated with zomato, given that India contains 
highest number of restaurants with zomato, let's carry out analysis on India'''

df_Zomato1=df_Zomato.groupby("Country").agg(Restaurant_Count=("Restaurant ID","count")).sort_values(by="Restaurant_Count",ascending=False)

# %%
df_Zomato1.plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='Country'>

# %%
data = df_Zomato[df_Zomato['Country']=="India"].reset_index(drop=True).copy()
nRow1, nCol1 = data.shape
print(f'Data has {nRow1} rows and {nCol1} columns.')
# Out:
# Data has 8652 rows and 22 columns.

# %%
# Checking if dataset contains any null
data.isna().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %%
#checking no. of restaurants partnered with Zomato per city
data['City'].value_counts()
# Out:
# New Delhi       5473
# Gurgaon         1118
# Noida           1080
# Faridabad        251
# Ghaziabad         25
# Ahmedabad         21
# Guwahati          21
# Lucknow           21
# Bhubaneshwar      21
# Amritsar          21
# Pune              20
# Puducherry        20
# Patna             20
# Ludhiana          20
# Ranchi            20
# Surat             20
# Vadodara          20
# Nashik            20
# Nagpur            20
# Mysore            20
# Mumbai            20
# Varanasi          20
# Mangalore         20
# Agra              20
# Kochi             20
# Kolkata           20
# Dehradun          20
# Allahabad         20
# Aurangabad        20
# Bangalore         20
# Bhopal            20
# Chennai           20
# Coimbatore        20
# Goa               20
# Indore            20
# Jaipur            20
# Kanpur            20
# Vizag             20
# Chandigarh        18
# Hyderabad         18
# Secunderabad       2
# Panchkula          1
# Mohali             1
# Name: City, dtype: int64

# %%
# To check no. of restaurants which have online delivery
data.groupby(['Has Online delivery']).size().reset_index()
# Out:
#   Has Online delivery     0
# 0                  No  6229
# 1                 Yes  2423

# %%
sns.countplot(data['Has Online delivery'])
# Out:
# /Users/prithvisnaidu/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Has Online delivery', ylabel='count'>

# %%
x=data.drop(['Country Code', 'Address','Locality Verbose','Longitude','Latitude','Is delivering now','Switch to order menu','Has Table booking','Currency'], axis=1)
x.head()
# Out:
#    Restaurant ID                        Restaurant Name  City     Locality  \
# 0        3400025                             Jahanpanah  Agra   Agra Cantt
# 1        3400341                    Rangrezz Restaurant  Agra   Agra Cantt
# 2        3400005                Time2Eat - Mama Chicken  Agra   Agra Cantt
# 3        3400021  Chokho Jeeman Marwari Jain Bhojanalya  Agra  Civil Lines
# 4        3400017                         Pinch Of Spice  Agra  Civil Lines
#
#                          Cuisines  Average Cost for two Has Online delivery  \
# 0           North Indian, Mughlai                   850                  No
# 1           North Indian, Mughlai                   700                  No
# 2                    North Indian                   500                  No
# 3                      Rajasthani                   400                  No
# 4  North Indian, Chinese, Mughlai                  1000                  No
#
#    Price range  Aggregate rating Rating color Rating text  Votes Country
# 0            3               3.9       Yellow        Good    140   India
# 1            2               3.5       Yellow        Good     71   India
# 2            2               3.6       Yellow        Good     94   India
# 3            2               4.0        Green   Very Good     87   India
# 4            3               4.2        Green   Very Good    177   India

# %%
# Since New Delhi has most number of restaurants partnered with zomato we can analyse which top 10 Localities has most restaurants within New Delhi 

x1=data[(data.City == 'New Delhi')]
x2=x1.Locality.value_counts().head(10)
x2.head(10)
# Out:
# Connaught Place        122
# Rajouri Garden          99
# Shahdara                87
# Defence Colony          86
# Pitampura               85
# Malviya Nagar           84
# Mayur Vihar Phase 1     84
# Rajinder Nagar          81
# Safdarjung              80
# Satyaniketan            79
# Name: Locality, dtype: int64

# %%
x2.plot(kind='bar')
plt.ylabel('Number of Restaurants')
plt.xlabel('Locality')
# Out:
# Text(0.5, 0, 'Locality')

# %%
df9 = data.groupby(['Cuisines'])
a=['Cuisines','Restaurant Name','Locality','City']
df9[a].head()
# Out:
#                                                Cuisines  \
# 0                                 North Indian, Mughlai
# 1                                 North Indian, Mughlai
# 2                                          North Indian
# 3                                            Rajasthani
# 4                        North Indian, Chinese, Mughlai
# ...                                                 ...
# 8645  South Indian, Chinese, Continental, Italian, N...
# 8646                                    Biryani, Andhra
# 8647  Continental, Seafood, Chinese, North Indian, B...
# 8649                             Burger, Pizza, Biryani
# 8650          American, North Indian, Thai, Continental
#
#                             Restaurant Name               Locality   City
# 0                                Jahanpanah             Agra Cantt   Agra
# 1                       Rangrezz Restaurant             Agra Cantt   Agra
# 2                   Time2Eat - Mama Chicken             Agra Cantt   Agra
# 3     Chokho Jeeman Marwari Jain Bhojanalya            Civil Lines   Agra
# 4                            Pinch Of Spice            Civil Lines   Agra
# ...                                     ...                    ...    ...
# 8645                            Six Degrees             MVP Colony  Vizag
# 8646             Sea Inn - Raju Gaari Dhaba             Rushikonda  Vizag
# 8647                               D Cabana            Sagar Nagar  Vizag
# 8649                                Plot 17              Siripuram  Vizag
# 8650                       Vista - The Park  The Park, Lawsons Bay  Vizag
#
# [2506 rows x 4 columns]

# %%
df5 = data.groupby(['Aggregate rating','Rating color', 'Rating text']).size().reset_index().rename(columns={0:'Rating Count'})
df5
# Out:
#     Aggregate rating Rating color Rating text  Rating Count
# 0                0.0        White   Not rated          2139
# 1                1.8          Red        Poor             1
# 2                1.9          Red        Poor             2
# 3                2.0          Red        Poor             7
# 4                2.1          Red        Poor            15
# 5                2.2          Red        Poor            26
# 6                2.3          Red        Poor            46
# 7                2.4          Red        Poor            83
# 8                2.5       Orange     Average           109
# 9                2.6       Orange     Average           190
# 10               2.7       Orange     Average           250
# 11               2.8       Orange     Average           314
# 12               2.9       Orange     Average           380
# 13               3.0       Orange     Average           465
# 14               3.1       Orange     Average           511
# 15               3.2       Orange     Average           510
# 16               3.3       Orange     Average           472
# 17               3.4       Orange     Average           477
# 18               3.5       Yellow        Good           454
# 19               3.6       Yellow        Good           411
# 20               3.7       Yellow        Good           363
# 21               3.8       Yellow        Good           336
# 22               3.9       Yellow        Good           283
# 23               4.0        Green   Very Good           193
# 24               4.1        Green   Very Good           185
# 25               4.2        Green   Very Good           140
# 26               4.3        Green   Very Good           100
# 27               4.4        Green   Very Good            74
# 28               4.5   Dark Green   Excellent            37
# 29               4.6   Dark Green   Excellent            35
# 30               4.7   Dark Green   Excellent            16
# 31               4.8   Dark Green   Excellent             9
# 32               4.9   Dark Green   Excellent            19
